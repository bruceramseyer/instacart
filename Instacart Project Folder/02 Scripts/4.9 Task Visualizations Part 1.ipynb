# %% [markdown]
# # 4.9 Task: Visualizations - Part 1

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# This script contains the following points:
# 1. Importing customer data
# 2. Reviewing shape and structure of dataframe
# 3. Performing EDA on customer data
# 4. Merge customer data with other orders_product data set

# %%
path=r'C:\Users\dell\Desktop\Career Foundry\0423_Instacart Analysis'

# %%
#Import customers
df_cust=pd.read_csv(os.path.join(path,'02 Data','Original Data','customers.csv'),index_col=False)

# %%
df_cust.head(20)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %% [markdown]
# # Preliminary dataframe review

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df_cust.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df_cust.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
#First Name column has Null values

# %%
df_cust[df_cust['First Name'].isnull()==True]
# Out:
#         user_id First Name    Surnam  Gender         STATE  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %%
# Upon review of data subset with null values:
# 1) a new variable won't add more value than the NaN status
# 2) cannot determine a value to impute
# 3) Project brief doesn't indicate identifying customer by full name is necessary, will remove First Name columne and use user_id and/or Surnam (if needed)

# %%
df_cust['date_joined'].value_counts()
# Out:
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: date_joined, Length: 1187, dtype: int64

# %%
df_cust[df_cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surnam, Gender, STATE, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# No duplicate values found

# %% [markdown]
# # Data Wrangling

# %%
df_cust.rename(columns={'Surnam':'last_name','Gender':'gender','STATE':'state','Age':'age','n_dependants':'num_dependants'},inplace=True)

# %%
df_cust.head()
# Out:
#    user_id First Name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    num_dependants fam_status  income
# 0               3    married  165665
# 1               0     single   59285
# 2               2    married   99568
# 3               0     single   42049
# 4               1    married   40374

# %%
df_cust_clean = df_cust.drop(['First Name'], axis=1)

# %%
df_cust_clean.head()
# Out:
#    user_id last_name  gender       state  age date_joined  num_dependants  \
# 0    26711  Esquivel  Female    Missouri   48    1/1/2017               3
# 1    33890      Hart  Female  New Mexico   36    1/1/2017               0
# 2    65803    Farley    Male       Idaho   35    1/1/2017               2
# 3   125935     Hicks  Female        Iowa   40    1/1/2017               0
# 4   130797   Gilmore  Female    Maryland   26    1/1/2017               1
#
#   fam_status  income
# 0    married  165665
# 1     single   59285
# 2    married   99568
# 3     single   42049
# 4    married   40374

# %% [markdown]
# # Combining Data

# %%
# Import pickle for order_products_combined data set
ords_prods_merge=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_agg.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    #ofdays_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                       0.0         196                  1          0
# 1                      15.0         196                  1          1
# 2                      21.0         196                  1          1
# 3                      29.0         196                  1          1
# 4                      28.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc  busiest_days  \
# ...

# %%
ords_prods_merge.dtypes
# Out:
# order_id                      int64
# user_id                       int64
# order_number                  int64
# orders_day_of_week            int64
# order_hour_of_day             int64
# #ofdays_since_last_order    float64
# product_id                    int64
# add_to_cart_order             int64
# reordered                     int64
# product_name                 object
# aisle_id                      int64
# department_id                 int64
# prices                      float64
# price_range_loc              object
# busiest_days                 object
# busiest_period_of_day        object
# max_order                     int64
# loyalty_flag                 object
# mean_spend                  float64
# spending_flag                object
# median_freq                 float64
# frequency_flag               object
# dtype: object

# %%
ords_prods_merge.shape
# Out:
# (32404859, 22)

# %%
# merging customer data to orders and product data

instacart_merge = ords_prods_merge.merge(df_cust_clean, on = 'user_id',indicator = True)

# %%
instacart_merge.shape
# Out:
# (32404859, 31)

# %%
instacart_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    #ofdays_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                       0.0         196                  1          0
# 1                      15.0         196                  1          1
# 2                      21.0         196                  1          1
# 3                      29.0         196                  1          1
# 4                      28.0         196                  1          1
#
#   product_name  ...    frequency_flag  last_name  gender    state age  \
# ...

# %%
# Export data to pkl

instacart_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'instacart_merge.pkl'))
